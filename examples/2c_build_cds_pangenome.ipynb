# %%
import os

import pandas as pd
from tqdm.notebook import tqdm

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px

plt.rcParams["figure.dpi"] = 200
sns.set_palette("deep")
sns.set_context("paper")
sns.set_style("whitegrid")

from pyphylon.util import load_config

# %%
CONFIG = load_config("config.yml")
WORKDIR = CONFIG["WORKDIR"]
SPECIES = CONFIG["PG_NAME"]
temp_folder = CONFIG.get("REUSE_TEMP_DIR", "../temp/")
data_dir = CONFIG.get("SNAKEMAKE_DATA_DIR", "data/")

# %%
mash_scrubbed_metadata = pd.read_csv(
    os.path.join(temp_folder, '2b_genome_metadata.csv'),
    index_col=0, dtype='object')

display(
    mash_scrubbed_metadata.shape,
    mash_scrubbed_metadata.head()
)
# Out:
# (373, 109)
#    genome_id public                  assembly_method patric_cds  \
# 0  1201032.3   True                              NaN       1659
# 1  1211776.3   True                              NaN       1690
# 2  1340842.3   True  Newbler v. 2.3; Geneious v. 9.1       1727
# 3  1347340.3   True                              NaN       1699
# 4  1349826.3   True  Newbler v. 2.6; Geneious v. 5.6       1853
#
#                                  taxon_lineage_names plasmids  \
# 0  ['cellular organisms', 'Bacteria', 'Pseudomona...      0.0
# 1  ['cellular organisms', 'Bacteria', 'Pseudomona...      0.0
# 2  ['cellular organisms', 'Bacteria', 'Pseudomona...      NaN
# 3  ['cellular organisms', 'Bacteria', 'Pseudomona...      0.0
# 4  ['cellular organisms', 'Bacteria', 'Pseudomona...      1.0
#
#   sequencing_depth genome_quality  \
# 0              NaN           Good
# 1              NaN           Good
# 2             122x           Good
# 3              NaN           Good
# 4             117x           Good
#
#                                  additional_metadata checkm_contamination  \
# 0                                                NaN                  0.0
# 1                                                NaN                  0.0
# 2  ['collected_by:M. A. Karmali, The Hospital for...                  0.0
# 3                                                NaN                  0.0
# 4                   ['collected_by:Dr. Bibiana Law']                  3.0
#
#    ... host_health other_environmental sra_accession other_typing pathovar  \
# 0  ...         NaN                 NaN           NaN          NaN      NaN
# 1  ...         NaN                 NaN           NaN          NaN      NaN
# 2  ...   enteritis                 NaN           NaN          NaN      NaN
# 3  ...         NaN                 NaN           NaN          NaN      NaN
# 4  ...         NaN                 NaN           NaN          NaN      NaN
#
#   reference_genome host_age host_gender altitude mash_cluster
# 0              NaN      NaN         NaN      NaN            4
# 1              NaN      NaN         NaN      NaN            7
# 2              NaN      NaN         NaN      NaN           29
# 3              NaN      NaN         NaN      NaN           24
# 4              NaN      NaN         NaN      NaN            7
#
# [5 rows x 109 columns]

# %%
BAKTA = os.path.join(data_dir, 'processed/bakta/')

bakta_faa_paths = [
    os.path.join(BAKTA, bakta_folder, bakta_folder + '.faa')
    for bakta_folder in os.listdir(BAKTA)
    if os.path.isdir(os.path.join(BAKTA, bakta_folder))
]

bakta_faa_paths[:5]
# Out:
# ['data/processed/bakta/1201032.3\\1201032.3.faa',
#  'data/processed/bakta/1211776.3\\1211776.3.faa',
#  'data/processed/bakta/1295010.3\\1295010.3.faa',
#  'data/processed/bakta/1338035.3\\1338035.3.faa',
#  'data/processed/bakta/1340842.3\\1340842.3.faa']

# %%
# Sanity check
for path in tqdm(bakta_faa_paths):
    assert os.path.isfile(path)
# Out:
#   0%|          | 0/467 [00:00<?, ?it/s]

# %%
genome_id_set = set(mash_scrubbed_metadata['genome_id'].astype(str))

real_paths = [
    f for f in bakta_faa_paths
    if os.path.basename(os.path.dirname(f)) in genome_id_set
]

print(f"Matched {len(real_paths)} BAKTA paths to metadata genomes.")
real_paths[:5]
# Out:
# Matched 355 BAKTA paths to metadata genomes.
# ['data/processed/bakta/1201032.3\\1201032.3.faa',
#  'data/processed/bakta/1211776.3\\1211776.3.faa',
#  'data/processed/bakta/1340842.3\\1340842.3.faa',
#  'data/processed/bakta/1347340.3\\1347340.3.faa',
#  'data/processed/bakta/1349826.3\\1349826.3.faa']

# %%
len(real_paths)
# Out:
# 355

# %%
from pyphylon.pangenome import build_cds_pangenome

cdhit_output_dir = os.path.join(data_dir, 'processed/cd-hit-results/')
os.makedirs(cdhit_output_dir, exist_ok=True)

df_alleles, df_genes, header_to_allele = build_cds_pangenome(
    genome_faa_paths=real_paths,
    output_dir=cdhit_output_dir,
    name=SPECIES,
    cdhit_args={'-n': 5, '-c': 0.8, '-aL': 0.8, '-T': 0, '-M': 0},
    fastasort_path=None,
    save_csv=False
)
# Out:
# Identifying non-redundant CDS sequences...
# Headers without sequences: 0
# Running: ['cd-hit', '-i', 'data/processed/cd-hit-results/CJejuni', '-o', 'data/processed/cd-hit-results/CJejuni.cdhit', '-d', '0', '-n', '5', '-c', '0.8', '-aL', '0.8', '-T', '0', '-M', '0']
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 6
#       3 cdhit_output_dir = os.path.join(data_dir, 'processed/cd-hit-results/')
#       4 os.makedirs(cdhit_output_dir, exist_ok=True)
# ----> 6 df_alleles, df_genes, header_to_allele = build_cds_pangenome(
#       7     genome_faa_paths=real_paths,
#       8     output_dir=cdhit_output_dir,
#       9     name=SPECIES,
#      10     cdhit_args={'-n': 5, '-c': 0.8, '-aL': 0.8, '-T': 0, '-M': 0},
#      11     fastasort_path=None,
#      12     save_csv=False
#      13 )
#
# File F:\lab_projects\pangenomics\pyphylon\pyphylon\pangenome.py:109, in build_cds_pangenome(genome_faa_paths, output_dir, name, cdhit_args, fastasort_path, save_csv)
#     107 output_nr_clstr = output_nr_faa + '.cdhit.clstr' # cluster file generated by CD-Hit
#     108 cluster_with_cdhit(output_nr_faa, output_nr_faa_copy, cdhit_args)
# --> 109 os.remove(output_nr_faa_copy) # delete CD-hit copied sequences
#     111 ''' Extract genes and alleles, rename unique sequences as <name>_C#A# '''
#     112 output_allele_names = output_dir + '/' + name + '_allele_names.tsv' # allele names vs non-redundant headers
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified: 'data/processed/cd-hit-results/CJejuni.cdhit'

# %%
df_genes.sum()

# %%
# sns.clustermap(df_genes.fillna(0).transpose()) TODO: Not providing much insight - sidd

# look at cluster core/accesory
